# %%
import pandas as pd
import numpy as np
import scipy.stats as ss
import indepth_functions
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")
from IPython.display import Image

# %%
df = pd.read_csv('../data/interim/census/household_shopping_concat.csv')

# %%
df_summary = pd.read_csv('../data/processed/shopping_statistics_msa.csv')

# %%
df['GENERATION'] = df.TBIRTH_YEAR.apply(indepth_functions.generation_)

# %%
df_summary.rename({'CHNGHOW4': 'RFID-NFC', 
                   'CHNGHOW5': 'CASH', 
                   'CHNGHOW6': 'AVOID RESTR',
                   'CHNGHOW7': 'RESUME RESTR'}, axis=1, inplace=True)

# %%
EST_MSA = 41860
name_location = 'San Francisco Bay Area'

# %%
df = df[df.EST_MSA == EST_MSA]

# %%
df1 = df.loc[:, ['CHNGHOW1', 'CHNGHOW2', 'CHNGHOW3', 'CHNGHOW4', 
                'CHNGHOW5', 'CHNGHOW6', 'CHNGHOW7']]

# %%
df1.rename({'CHNGHOW1': 'ONLINE',
           'CHNGHOW2': 'PICK-UP',
           'CHNGHOW3': 'IN-STORE',
           'CHNGHOW4': 'RFID-NFC', 
           'CHNGHOW5': 'CASH', 
           'CHNGHOW6': 'AVOID RESTR',
           'CHNGHOW7': 'RESUME RESTR'}, axis=1, inplace=True)

# %%
corr = df1.replace({np.nan: 0}).corr()

mask = np.zeros_like(corr)
mask[np.triu_indices_from(mask)] = True

with sns.axes_style("white"):
    f, ax = plt.subplots(figsize=(8.5, 8.5))
    ax = sns.heatmap(corr, 
                     mask=mask, 
                     vmax=.3, 
                     square=True, 
                     cmap="coolwarm_r", 
                     annot=True, 
                     fmt='1.2f',
                     annot_kws={"size": 18})
_ = plt.rcParams.update({'font.size': 22})

# %% [markdown]
# #### Avoid eating at restaurants

# %%
def cramers_v(x, y):
    confusion_matrix = pd.crosstab(x,y)
    chi2 = ss.chi2_contingency(confusion_matrix)[0]
    n = confusion_matrix.sum().sum()
    phi2 = chi2/n
    r,k = confusion_matrix.shape
    phi2corr = max(0, phi2-((k-1)*(r-1))/(n-1))
    rcorr = r-((r-1)**2)/(n-1)
    kcorr = k-((k-1)**2)/(n-1)
    return np.sqrt(phi2corr/min((kcorr-1),(rcorr-1)))

def cramers_matrix(df, location,name_location, shopping_variable, name_variable):
    corr = []
    demographics = ['EGENDER', 'RHISPANIC', 
                    'RRACE', 'GENERATION',
                    'EEDUC', 'MS', 'THHLD_NUMPER', 
                    'THHLD_NUMKID', 'THHLD_NUMADLT']
    
    df = df[df.EST_MSA == location].loc[:, [shopping_variable] + demographics].replace({np.nan: 0})
    df.rename({shopping_variable: name_variable}, axis=1, inplace=True)

    for var in demographics:
        c = cramers_v(df[name_variable], df[var])
        corr.append(c)
    a = pd.DataFrame(corr, index=demographics)
    a = a.rename(columns={0:name_variable})
    a['ABS_CHNGHOW'] = abs(a[name_variable]) 
    varsx = list(a['ABS_CHNGHOW'][1:].sort_values(ascending=False)[:3].index)

    print('Variables more correlated to '+name_variable+': \n{}'.format(a.loc[varsx, :][name_variable]))

    a.drop(columns=['ABS_CHNGHOW'], inplace=True)
    mask = np.zeros_like(a)
    mask[np.triu_indices_from(mask)] = True

    with sns.axes_style("white"):
        f, ax = plt.subplots(figsize=(10, 10))
        ax = sns.heatmap(a, square=True, cmap="coolwarm_r", annot=True, fmt='1.2f', annot_kws={"size": 18})
       # _ = plt.title('DEMOGRAPHICS AND '+name_variable, size=16)
        _ = plt.rcParams.update({'font.size': 22})

# %%
shopping_variable = 'CHNGHOW6'
name_variable = 'AVOID RESTR'
cramers_matrix(df, EST_MSA, name_location, shopping_variable, name_variable)
# Out:
# Variables more correlated to AVOID RESTR:
# EEDUC         0.062126
# MS            0.058755
# GENERATION    0.055900
# Name: AVOID RESTR, dtype: float64

# %%
shopping_variable = 'CHNGHOW5'
name_variable = 'CASH'
cramers_matrix(df, EST_MSA, name_location, shopping_variable, name_variable)
# Out:
# Variables more correlated to CASH:
# EEDUC    0.080863
# RRACE    0.052480
# MS       0.048093
# Name: CASH, dtype: float64

# %%
shopping_variable = 'CHNGHOW1'
name_variable = 'ONLINE'
cramers_matrix(df, EST_MSA, name_location, shopping_variable, name_variable)
# Out:
# Variables more correlated to ONLINE:
# EEDUC         0.144190
# GENERATION    0.107659
# MS            0.104864
# Name: ONLINE, dtype: float64

# %%
shopping_variable = 'CHNGHOW3'
name_variable = 'IN-STORE'
cramers_matrix(df, EST_MSA, name_location, shopping_variable, name_variable)
# Out:
# Variables more correlated to IN-STORE:
# EEDUC         0.096438
# RHISPANIC     0.059965
# GENERATION    0.056897
# Name: IN-STORE, dtype: float64

# %%
shopping_variable = 'CHNGHOW7'
name_variable = 'RESUME RESTR'
cramers_matrix(df, EST_MSA, name_location, shopping_variable, name_variable)
# Out:
# Variables more correlated to RESUME RESTR:
# GENERATION    0.038355
# RRACE         0.037859
# EEDUC         0.036555
# Name: RESUME RESTR, dtype: float64

# %%
shopping_variable = 'CHNGHOW2'
name_variable = 'PICK-UP'
cramers_matrix(df, EST_MSA, name_location, shopping_variable, name_variable)
# Out:
# Variables more correlated to PICK-UP:
# GENERATION      0.137540
# THHLD_NUMPER    0.096639
# MS              0.095371
# Name: PICK-UP, dtype: float64

# %%
shopping_variable = 'CHNGHOW4'
name_variable = 'RFID-NFC'
cramers_matrix(df, EST_MSA, name_location, shopping_variable, name_variable)
# Out:
# Variables more correlated to RFID-NFC:
# EEDUC         0.084670
# GENERATION    0.077651
# MS            0.070796
# Name: RFID-NFC, dtype: float64

# %% [markdown]
# ## Section 2: Mobility Trends

# %%
df_descartes_counties = pd.read_csv('../data/interim/mobility/m50_max_counties.csv')
df_descartes_counties_percent = pd.read_csv('../data/interim/mobility/m50_percent_counties.csv')

# %%
df_apple = pd.read_csv('../data/interim/mobility/apple_mobility_cities.csv', index_col=0)

# %%
df_foursquare_dma = pd.read_csv('../data/interim/mobility/foursquare_dma.csv', index_col=0)
df_google = pd.read_csv('../data/interim/mobility/google_counties.csv', index_col=0)

# %%
def indexed_mobility_average_person(df, location):
    df_index = df[df.NAME == location].loc[:, '2020-03-01':]

    df_index = pd.melt(df_index, var_name='date', value_name='index')
    df_index['date'] = pd.to_datetime(df_index['date'])
    df_index['city'] = location
    
#     f, ax = plt.subplots(figsize=(15.5, 4.5))
#     _ = plt.rcParams.update({'font.size': 22})
#     _ = sns.lineplot(data=df_index, x='date', y='index')
#     _ = plt.axhline(y=100, color='k', linestyle='--', label='Baseline', lw=0.5)
#     _ = plt.xlabel('Date')
#     _ = plt.ylabel('Indexed mobility')
#     _ = plt.title('Indexed mobility for a regular person \n'+location) 
    
    return df_index

def mobility_average_person(df, location):
    df_kms= df[df.NAME == location].loc[:, '2020-03-01':]

    df_kms = pd.melt(df_kms, var_name='date', value_name='kms')
    df_kms['date'] = pd.to_datetime(df_kms['date'])
    df_kms['city'] = location
    
#     f, ax = plt.subplots(figsize=(15.5, 4.5))
#     _ = plt.rcParams.update({'font.size': 22})
#     _ = sns.lineplot(data=df_kms, x='date', y='kms')
#     _ = plt.xlabel('Date')
#     _ = plt.ylabel('Kms')
#     _ = plt.title('Mobility for a regular person \n'+location)   
    
    return df_kms

# %%
location = 'San Francisco County'

# %%
import pandas as pd
import numpy as np
import scipy.stats as ss
import matplotlib.pyplot as plt
import seaborn as sns
from statsmodels.tsa.seasonal import seasonal_decompose


def serie_decomposition(df, colname, model, display, location):

    df = df[df.city == location]
    df.date = pd.to_datetime(df.date)
    df.set_index('date', inplace=True)

    if df[colname].isnull().any():
        df.fillna(method='ffill', inplace=True)
    result_add = seasonal_decompose(df[colname], model=model, extrapolate_trend='freq')
    df_reconstructed = pd.concat([result_add.seasonal, result_add.trend, result_add.resid, result_add.observed], axis=1)
    df_reconstructed.columns = ['seas', 'trend', 'resid', 'actual_values']
        
    return df_reconstructed

def compile_decomposition(df, variable_decomposition, location):
# Display a plot with the selected variable decomposition for driving, walking and transit
    out1 = serie_decomposition(df, 'trn', 'additive', False, location)

    out2 = serie_decomposition(df, 'drv', 'additive', False, location)

    out3 = serie_decomposition(df, 'wlk', 'additive', False, location)

    _ = plt.figure(figsize=(15.5, 4.5))

    if variable_decomposition == 'trend':
        _ = plt.plot(out1.trend, label='Transit routes')
        _ = plt.plot(out2.trend, label='Driving routes')
        _ = plt.plot(out3.trend, label='Walking routes')
    elif variable_decomposition == 'residual':
        _ = plt.plot(out1.resid, label='Transit routes')
        _ = plt.plot(out2.resid, label='Driving routes')
        _ = plt.plot(out3.resid, label='Walking routes')
    else:
        _ = plt.plot(out1.seas, label='Transit routes')
        _ = plt.plot(out2.seas, label='Driving routes')
        _ = plt.plot(out3.seas, label='Walking routes')

# %%
def mobility_venues_foursquare(df, location):
    df = df[[location,'class']]
    df.index = pd.to_datetime(df.index)
    
    temp = df.groupby('class').count().reset_index()
    max_data = max(temp[location])
    #only display historical data with 80% of the longer serie
    valid_venues = list(temp[temp[location] >= 0.8*max_data]['class'])
    

    return df[df['class'].isin(valid_venues)]

def mobility_venues_google(df, location):
    df = df[df.NAME == location]
    df1 = pd.melt(df, id_vars=['NAME', 'category'], var_name='Date')
    df1.Date = pd.to_datetime(df1.Date)
    temp = df1.groupby('category').count().reset_index()

    max_data = max(temp['value'])
    #only display historical data with 80% of the longer serie
    valid_venues = list(temp[temp['value'] >= 0.8*max_data]['category'])

    return df1[df1['category'].isin(valid_venues)]

# %%
df_index = indexed_mobility_average_person(df_descartes_counties, location)
df_kms = mobility_average_person(df_descartes_counties_percent, location)

# %%
location = 'San Francisco - Bay Area'
out1 = serie_decomposition(df_apple, 'trn', 'additive', False, location)
out2 = serie_decomposition(df_apple, 'drv', 'additive', False, location)
out3 = serie_decomposition(df_apple, 'wlk', 'additive', False, location)

# %%
df_mobility_venues_foursquare = mobility_venues_foursquare(df_foursquare_dma, 'SanFrancisco-Oakland-SanJose')
df_mobility_venues_google = mobility_venues_google(df_google, 'San Francisco County')

# %%
df_index.head()
# Out:
#         date  index                  city
# 0 2020-03-01   77.0  San Francisco County
# 1 2020-03-02   97.0  San Francisco County
# 2 2020-03-03   95.0  San Francisco County
# 3 2020-03-04  101.0  San Francisco County
# 4 2020-03-05  100.0  San Francisco County

# %%
df_index['location'] = 'San Francisco'
df_index['src'] = 'indexed regular member'
df_index['value'] = df_index['index']
df_kms['location'] = 'San Francisco'
df_kms['src'] = 'mobility regular member'
df_kms['value'] = df_kms['kms']

# %%
df_index.head()
# Out:
#         date  index                  city       location  \
# 0 2020-03-01   77.0  San Francisco County  San Francisco
# 1 2020-03-02   97.0  San Francisco County  San Francisco
# 2 2020-03-03   95.0  San Francisco County  San Francisco
# 3 2020-03-04  101.0  San Francisco County  San Francisco
# 4 2020-03-05  100.0  San Francisco County  San Francisco
#
#                       src  value
# 0  indexed regular member   77.0
# 1  indexed regular member   97.0
# 2  indexed regular member   95.0
# 3  indexed regular member  101.0
# 4  indexed regular member  100.0

# %%
df_mobility_venues_foursquare = df_mobility_venues_foursquare.reset_index().rename({' ':'date'}, axis=1)
df_mobility_venues_foursquare['location'] = 'San Francisco'
df_mobility_venues_foursquare['source'] = 'venues foursquare'
df_mobility_venues_foursquare['value'] = df_mobility_venues_foursquare['SanFrancisco-Oakland-SanJose']

# %%
df_mobility_venues_google = df_mobility_venues_google.reset_index().rename({'Date':'date', 'category': 'class'}, axis=1)
df_mobility_venues_google['location'] = 'San Francisco'
df_mobility_venues_google['source'] = 'venues google'
df_mobility_venues_google['value'] = df_mobility_venues_google['value']

# %%
out1 = out1.reset_index()
out1['src'] = 'transit'
out1['location'] = 'San Francisco'
out1['value'] = out1['actual_values']

out2 = out2.reset_index()
out2['src'] = 'driving'
out2['value'] = out2['actual_values']

out3 = out3.reset_index()
out3['src'] = 'walking'
out3['value'] = out3['actual_values']

# %%
df1 = df_index.loc[:, ['date', 'location', 'src', 'value']]
df2 = df_kms.loc[:, ['date', 'location', 'src', 'value']]
df3 = out1.loc[:, ['date', 'location', 'src', 'value']]
df4 = out2.loc[:, ['date', 'location', 'src', 'value']]
df5 = out3.loc[:, ['date', 'location', 'src', 'value']]
df6 = df_mobility_venues_foursquare.loc[:, ['date', 'location', 'source', 'value', 'class']]
df7 = df_mobility_venues_google.loc[:, ['date', 'location', 'source', 'value', 'class']]

# %%
df_compilation1 = pd.concat([df1, df2, df3, df4, df5])

# %%
df_compilation1.head()
# Out:
#         date       location                     src  value
# 0 2020-03-01  San Francisco  indexed regular member   77.0
# 1 2020-03-02  San Francisco  indexed regular member   97.0
# 2 2020-03-03  San Francisco  indexed regular member   95.0
# 3 2020-03-04  San Francisco  indexed regular member  101.0
# 4 2020-03-05  San Francisco  indexed regular member  100.0

# %%
#df_compilation1.to_csv('../data/processed/mobility_compilation_index.csv', index=False)

# %%
df_compilation2 = pd.concat([df6, df7])
df_compilation2.to_csv('../data/processed/mobility_compilation_venues.csv', index=False)

# %% [markdown]
# ## Section 3: Restaurants
#
# The following analysis includes 50 businesses/every zip code of San Francisco county. The information of the restaurants was extracted using FUSION API Yelp, which allows a maximum of 50 results for endpoint using the zip codes as keywords and words as Restaurant.

# %%
df_restaurants = pd.read_csv('../data/interim/restaurants/yelp_sf.csv')

# %%
df_restaurants.head()
# Out:
#                       ids                    names  rating  review_count  \
# 0  vmZ-bgnM5B76NUpegAjy1g                  Hotbird     4.5           131
# 1  pgjbSwK_8DH2o_zQsr3dRQ      AshYan's Lu Ruo Fan     5.0             4
# 2  KA-P3d2NcbJy5SQN-vCzPA  Aria Korean Street Food     4.0           891
# 3  kFgjHGp-cTUK5uPaSJOORA                   Souvla     4.0          1418
# 4  sk2OH92GwQjFKbguoFWHSw               Uncle Tito     4.0             1
#
#   price            transactions  is_closed  \
# 0   NaN                     NaN      False
# 1   NaN                     NaN      False
# 2    $$  ['pickup', 'delivery']      False
# 3    $$            ['delivery']      False
# 4   NaN                     NaN      False
#
#                                   type_food  \
# 0         Sandwiches, Chicken Shop, Burgers
# 1         Taiwanese, Food Delivery Services
# 2  Korean, Tapas/Small Plates, Chicken Shop
# 3                      Greek, Mediterranean
# 4                                  Filipino
#
#                         type_food_alias   latitude   longitude country state  \
# 0      sandwiches, chickenshop, burgers  37.776800 -122.416264      US    CA
# 1       taiwanese, fooddeliveryservices  37.777130 -122.419640      US    CA
# 2  korean, tapasmallplates, chickenshop  37.786550 -122.417950      US    CA
# 3                  greek, mediterranean  37.776430 -122.425000      US    CA
# 4                              filipino  37.776902 -122.415244      US    CA
#
#             city  zip_code
# 0  San Francisco   94103.0
# 1  San Francisco       NaN
# 2  San Francisco   94109.0
# 3  San Francisco   94102.0
# 4  San Francisco   94103.0

# %%
df_restaurants['purchase'] = df_restaurants['transactions'].apply(indepth_functions.transaction_cleaning)

# %%
df_restaurants['pickup_delivery'] = df_restaurants['purchase'].apply(indepth_functions.check_pickup_delivery)

# %%
df_restaurants.head()
# Out:
#                       ids                    names  rating  review_count  \
# 0  vmZ-bgnM5B76NUpegAjy1g                  Hotbird     4.5           131
# 1  pgjbSwK_8DH2o_zQsr3dRQ      AshYan's Lu Ruo Fan     5.0             4
# 2  KA-P3d2NcbJy5SQN-vCzPA  Aria Korean Street Food     4.0           891
# 3  kFgjHGp-cTUK5uPaSJOORA                   Souvla     4.0          1418
# 4  sk2OH92GwQjFKbguoFWHSw               Uncle Tito     4.0             1
#
#   price            transactions  is_closed  \
# 0   NaN                     NaN      False
# 1   NaN                     NaN      False
# 2    $$  ['pickup', 'delivery']      False
# 3    $$            ['delivery']      False
# 4   NaN                     NaN      False
#
#                                   type_food  \
# 0         Sandwiches, Chicken Shop, Burgers
# 1         Taiwanese, Food Delivery Services
# 2  Korean, Tapas/Small Plates, Chicken Shop
# 3                      Greek, Mediterranean
# 4                                  Filipino
#
#                         type_food_alias   latitude   longitude country state  \
# 0      sandwiches, chickenshop, burgers  37.776800 -122.416264      US    CA
# 1       taiwanese, fooddeliveryservices  37.777130 -122.419640      US    CA
# 2  korean, tapasmallplates, chickenshop  37.786550 -122.417950      US    CA
# 3                  greek, mediterranean  37.776430 -122.425000      US    CA
# 4                              filipino  37.776902 -122.415244      US    CA
#
#             city  zip_code            purchase      pickup_delivery
# 0  San Francisco   94103.0                 NaN                  NaN
# 1  San Francisco       NaN                 NaN                  NaN
# 2  San Francisco   94109.0  [pickup, delivery]  pickup and delivery
# 3  San Francisco   94102.0          [delivery]        only delivery
# 4  San Francisco   94103.0                 NaN                  NaN

# %%
df_restaurants.type_food.unique()
# Out:
# array(['Sandwiches, Chicken Shop, Burgers',
#        'Taiwanese, Food Delivery Services',
#        'Korean, Tapas/Small Plates, Chicken Shop', 'Greek, Mediterranean',
#        'Filipino', 'Gastropubs', 'Dim Sum, Noodles, Asian Fusion',
#        'Breakfast & Brunch, Southern, Cajun/Creole',
#        'Chicken Wings, Fast Food, Asian Fusion',
#        'Burmese, Indonesian, Noodles',
#        'Pop-Up Restaurants, Caterers, Indonesian', 'American (New)',
#        'Korean', 'Mexican', 'Chinese, Vietnamese, Noodles',
#        'Venezuelan, Personal Chefs, Caterers',
#        'Mexican, Pop-Up Restaurants', 'Korean, Soup, Noodles', 'Pizza',
#        'Vietnamese, Sandwiches', 'Thai', 'Vietnamese, Noodles, Soup',
#        'Indian, Pakistani, Halal', 'Korean, Fast Food',
#        'Scandinavian, Bars', 'Asian Fusion, Hawaiian, Poke',
#        'Bars, American (New), Seafood',
#        'American (New), Cocktail Bars, Wine Bars', 'Sushi Bars, Japanese',
#        'American (Traditional)', 'Japanese', 'Vietnamese',
#        'Italian, Cocktail Bars, Pizza',
#        'Spanish, Seafood, Tapas/Small Plates',
#        'Spanish, Seafood, Tapas Bars',
#        'Italian, Pasta Shops, Cooking Classes', 'Chicken Shop, Sandwiches',
#        'Italian', 'French', 'American (New), Bars', 'Italian, French',
#        'Falafel', 'Tea Rooms, French, Bakeries',
#        'Vietnamese, Seafood, Noodles', 'Noodles, Food Trucks, Szechuan',
#        'Chicken Shop', 'Japanese, Sushi Bars', 'Hawaiian, Poke, Filipino',
#        'Food Trucks, Indian', 'Mediterranean, Tapas/Small Plates',
#        'Mediterranean, Middle Eastern, Greek', 'Middle Eastern, Falafel',
#        'Russian, Ukrainian, Soup', 'Japanese Curry', 'Sushi Bars',
#        'American (New), Cocktail Bars',
#        'Cambodian, Asian Fusion, Chicken Wings', 'Italian, Bars',
#        'Mexican, Bars, Salad', 'Chinese',
#        'American (Traditional), Cocktail Bars', 'Seafood',
#        'Chinese, Lounges, Seafood', 'Himalayan/Nepalese, Food Stands',
#        'Seafood, American (Traditional)',
#        'Asian Fusion, Venues & Event Spaces',
#        'Middle Eastern, Cocktail Bars, Wine Bars',
#        'Cocktail Bars, American (Traditional)',
#        'Japanese, Sushi Bars, Asian Fusion',
#        'Southern, American (Traditional), Bars', 'Dim Sum, Cantonese',
#        'Seafood, Cantonese', 'French, Venues & Event Spaces',
#        'German, Food Trucks', 'Ramen', 'Brasseries, French, Cocktail Bars',
#        'Asian Fusion, Caterers', 'Tacos',
#        'Salad, Cheese Shops, Sandwiches', 'Pop-Up Restaurants',
#        'Mediterranean, Middle Eastern',
#        'Japanese, Sushi Bars, Cocktail Bars',
#        'Burgers, American (Traditional)', 'Hawaiian',
#        'Puerto Rican, Sandwiches', 'Salad, Pasta Shops, Sandwiches',
#        'Pop-Up Restaurants, Bagels',
#        'American (Traditional), Steakhouses, Wine Bars',
#        'Lounges, Cocktail Bars, American (New)', 'Thai, Comfort Food',
#        'Dim Sum, Asian Fusion', 'Chicken Shop, Noodles, Asian Fusion',
#        'Singaporean', 'Seafood, Seafood Markets, Live/Raw Food',
#        'Ethiopian', 'Izakaya', 'Szechuan', 'Arabian, Pop-Up Restaurants',
#        'Korean, Caterers', 'Himalayan/Nepalese',
#        'Food Stands, Burgers, Waffles',
#        'Seafood, American (New), Live/Raw Food',
#        'Sushi Bars, Japanese, Steakhouses', 'Spanish, Tapas/Small Plates',
#        'Japanese, Beer, Wine & Spirits', 'American (New), Barbeque',
#        'Latin American, Seafood, Peruvian', 'Argentine, Empanadas',
#        'American (New), Wine Bars, Cocktail Bars',
#        'Barbeque, American (New), Cocktail Bars',
#        'Basque, Spanish, Tapas Bars',
#        'Steakhouses, Bars, Venues & Event Spaces',
#        'Sandwiches, Food Trucks, Specialty Food', 'Delis',
#        'Seafood, Steakhouses', 'American (New), Wine Bars, Seafood',
#        'Ice Cream & Frozen Yogurt, Salad, Burgers',
#        'Korean, Asian Fusion, Mexican', 'Mediterranean, Salad, Sandwiches',
#        'Lounges, Cocktail Bars, Tapas/Small Plates',
#        'Mexican, Korean, Latin American', 'Gastropubs, Beer Bar',
#        'American (Traditional), Beer Bar', 'Asian Fusion, Tiki Bars',
#        'Steakhouses',
#        'Breakfast & Brunch, Cocktail Bars, Tapas/Small Plates',
#        'Italian, Pizza', 'American (New), Cocktail Bars, Bowling',
#        'Pizza, Italian',
#        'American (New), Breakfast & Brunch, Cocktail Bars',
#        'Bakeries, Dim Sum, Cantonese', 'Sushi Bars, Japanese, Bars',
#        'Pizza, Italian, Salad',
#        'Lounges, American (New), Breakfast & Brunch',
#        'Mexican, Cocktail Bars', 'Food Trucks, Asian Fusion',
#        'Dim Sum, Cantonese, Noodles', 'Pop-Up Restaurants, Dim Sum',
#        'Noodles, Szechuan', 'Burgers', 'Donuts, Desserts, Sandwiches',
#        'Spanish, Tapas Bars, Wine Bars', 'Malaysian', 'Restaurants',
#        'Chinese, Pop-Up Restaurants',
#        'Food Trucks, Indonesian, Asian Fusion',
#        'Thai, Chicken Shop, Food Trucks', 'Seafood, Italian, Bars',
#        'Mediterranean, Middle Eastern, Kebab', 'Brazilian, Food Trucks',
#        'Cafes, Hawaiian, Bakeries', 'Filipino, Pop-Up Restaurants',
#        'French, Burgers, Creperies', 'Argentine, Food Trucks, Empanadas',
#        'Persian/Iranian, Diners, Cafes',
#        'Southern, Cajun/Creole, American (Traditional)', 'Caribbean',
#        'Chinese, Asian Fusion, Noodles', 'Ramen, Sushi Bars',
#        'Puerto Rican', 'Latin American, Peruvian',
#        'Steakhouses, Tapas/Small Plates, Latin American',
#        'Korean, Mexican, Asian Fusion', 'Kebab, Turkish, Mediterranean',
#        'Cocktail Bars, Hungarian, Modern European',
#        'Chicken Shop, Food Delivery Services', 'Pizza, Breweries',
#        'American (Traditional), Comfort Food, Wine Bars',
#        'Seafood, Cajun/Creole, American (New)', 'Burmese, Chinese',
#        'Japanese, Sushi Bars, Soup', 'Vegan, Southern, Burgers',
#        'Seafood, Sandwiches, Burgers',
#        'Chicken Shop, Sandwiches, Soul Food',
#        'Spanish, Basque, Tapas Bars',
#        'Halal, Asian Fusion, Middle Eastern', 'Seafood, Fish & Chips',
#        'Peruvian, Tapas/Small Plates', 'Nicaraguan',
#        'Mediterranean, Moroccan, Lounges', 'Comfort Food',
#        'Mexican, Sports Bars', 'British, Fish & Chips, Seafood',
#        'Spanish, American (New), Seafood',
#        'Japanese, Peruvian, Cocktail Bars', 'Modern European, Fondue',
#        'Italian, Seafood, Wine Bars', 'Pop-Up Restaurants, Mexican',
#        'Salad, Delis, Sandwiches', 'Modern European, American (New)',
#        'Italian, Pasta Shops, International Grocery',
#        'German, Austrian, Bars', 'Chicken Wings, Waffles, Sandwiches',
#        'Wine Bars, Lounges, French', 'Italian, Pasta Shops, Desserts',
#        'Tapas/Small Plates, American (New), Desserts',
#        'Wine Bars, American (New), Venues & Event Spaces',
#        'Dim Sum, Seafood, Cantonese',
#        'Pizza, Italian, Beer, Wine & Spirits',
#        'Southern, American (New), Cajun/Creole', 'Korean, Chicken Wings',
#        'Southern, Soul Food, Waffles', 'Indian, Food Stands',
#        'Bubble Tea, Korean, Hot Dogs', 'Bars, Korean',
#        'Hawaiian, Barbeque', 'Grocery, Korean, Barbeque',
#        'Caribbean, Pop-Up Restaurants', 'Asian Fusion, Noodles',
#        'Japanese, Noodles', 'Bakeries, Desserts, Japanese',
#        'Seafood, Sardinian', 'Halal, Indian, Pakistani',
#        'Italian, Seafood, Gluten-Free', 'Asian Fusion, Noodles, Chinese',
#        'American (New), Wine Bars', 'Pizza, Wine Bars, Italian',
#        'Seafood, Salad, Sandwiches', 'Mexican, Tex-Mex, Latin American',
#        'Basque, French', 'Seafood, Bars, American (New)',
#        'Pizza, Italian, Cocktail Bars', 'Steakhouses, Bars',
#        'Chinese, Noodles, Hot Pot', 'Mediterranean, Turkish', 'Kebab',
#        'Seafood, American (New)', 'Thai, Gluten-Free',
#        'Cafes, Bubble Tea, Tea Rooms',
#        'Mediterranean, Bakeries, Sandwiches',
#        'Sports Bars, Burgers, Hot Dogs', 'Sandwiches, Cheesesteaks',
#        'Mexican, Seafood, Breakfast & Brunch',
#        'Middle Eastern, Mediterranean, Armenian',
#        'American (Traditional), Breakfast & Brunch, Burgers',
#        'Cafes, Sandwiches', 'Sushi Bars, Bars',
#        'Japanese, Korean, Gluten-Free', 'Korean, Noodles, Soup',
#        'Hawaiian, Bars, Venues & Event Spaces',
#        'American (Traditional), Barbeque',
#        'Mediterranean, Sandwiches, Salad', 'American (New), Italian',
#        'Pop-Up Restaurants, Southern', 'Grocery, Delis, Sandwiches',
#        'Tapas/Small Plates, Lounges, Izakaya', 'Poke, Sushi Bars',
#        'Italian, Wine Bars, Breakfast & Brunch', 'Italian, Wine Bars',
#        'Chinese, Japanese', 'Bakeries, Salad, Coffee Roasteries',
#        'Dim Sum, Szechuan', 'Comfort Food, Cocktail Bars, Wine Bars',
#        'Mediterranean, Greek', 'Arabian, Mediterranean, Lebanese',
#        'Bars, Seafood, Cajun/Creole', 'German, Comfort Food, Breweries',
#        'German, Burgers', 'Caribbean, Cuban, Tapas Bars',
#        'Vietnamese, Noodles',
#        'American (New), Wine Bars, Breakfast & Brunch',
#        'American (New), Desserts, Cocktail Bars',
#        'Seafood, Bars, Seafood Markets',
#        'American (New), Gluten-Free, Chicken Wings',
#        'Brazilian, Salad, Seafood', 'Desserts, Food Stands',
#        'Burmese, Cocktail Bars, Seafood',
#        'Italian, Pizza, Breakfast & Brunch', 'Burmese',
#        'Chinese, Asian Fusion', 'Thai, Chicken Shop',
#        'Chinese, Chicken Wings, Noodles',
#        'Latin American, Puerto Rican, Breakfast & Brunch',
#        'Middle Eastern, Mediterranean',
#        'Singaporean, Malaysian, Indonesian',
#        'Cafes, Soul Food, Breakfast & Brunch', 'Dim Sum',
#        'Burgers, American (New)',
#        'Pubs, Sports Bars, American (Traditional)', 'Thai, Noodles',
#        'Chicken Wings, Beer Bar', 'Korean, Barbeque',
#        'Breweries, American (Traditional), Venues & Event Spaces',
#        'Pizza, Gluten-Free, Chicken Wings', 'Bubble Tea, Sandwiches',
#        'Hookah Bars, Cafes, Middle Eastern', 'Cafes',
#        'Seafood, Vietnamese', 'Cafes, Portuguese, Beer, Wine & Spirits',
#        'Shanghainese, Taiwanese', 'Pizza, Salad', 'Sandwiches',
#        'Seafood, Tacos', 'Seafood, Chicken Wings, Cajun/Creole',
#        'Karaoke, Sports Bars, Taiwanese',
#        'Seafood, Vietnamese, Asian Fusion',
#        'Chinese, Bubble Tea, Shaved Ice', 'Vietnamese, Chinese, Noodles',
#        'Grocery, Chinese, Food Delivery Services',
#        'Chinese, Seafood, Noodles', 'Chicken Wings, Korean',
#        'Chinese, Barbeque', 'Noodles',
#        'Middle Eastern, Turkish, Mediterranean', 'Cocktail Bars, Mexican',
#        'Barbeque, Korean, Beer Bar', 'Chinese, Seafood',
#        'Chinese, Noodles', 'Indian', 'Sports Bars, Chicken Wings, Burgers',
#        'Bubble Tea, Juice Bars & Smoothies, Pancakes',
#        'Ramen, Izakaya, Noodles', 'Noodles, Chinese, Soup',
#        'Greek, Turkish, Mediterranean', 'Kebab, Turkish, Wraps',
#        'Korean, Salad, Seafood',
#        'Burmese, Asian Fusion, Breakfast & Brunch',
#        'Middle Eastern, Mediterranean, Kosher', 'Burgers, Fast Food',
#        'Barbeque, Pop-Up Restaurants, American (Traditional)',
#        'Szechuan, Dim Sum, Noodles',
#        'Latin American, Peruvian, Comfort Food',
#        'Cafes, Seafood, Mediterranean',
#        'Acai Bowls, Vegan, Juice Bars & Smoothies', 'Szechuan, Dim Sum',
#        'Vietnamese, Sandwiches, Noodles', 'Shanghainese',
#        'Bakeries, Breakfast & Brunch', 'Bars, American (New), Sandwiches',
#        'Vietnamese, Soup, Chicken Wings', 'Thai, Burmese',
#        'Barbeque, Korean, Soup', 'Italian, Pizza, Wine Bars',
#        'Food Delivery Services, Bakeries, Comfort Food',
#        'Taiwanese, Asian Fusion', 'Pizza, Salad, Wine Bars',
#        'Moroccan, Wine Bars, Cocktail Bars', 'Burgers, Sandwiches',
#        'Mediterranean', 'Wine Bars, Sandwiches',
#        'Cantonese, Hong Kong Style Cafe', 'Moroccan, Dinner Theater',
#        'Shanghainese, Dim Sum', 'Vietnamese, Coffee & Tea, Sandwiches',
#        'Korean, Asian Fusion, Ramen',
#        'Vietnamese, Ice Cream & Frozen Yogurt, Sandwiches',
#        'Breakfast & Brunch, American (New), Halal',
#        'Thai, Breakfast & Brunch, Asian Fusion',
#        'Burmese, Seafood, Noodles', 'Japanese, Cocktail Bars, Sushi Bars',
#        'Gastropubs, Bars, American (New)',
#        'American (New), Modern European, Bakeries',
#        'Wraps, Bubble Tea, Fast Food', 'Thai, Noodles, Chicken Wings',
#        'Delis, Sandwiches, Cheese Shops', 'Indian, Pakistani',
#        'Pizza, Italian, Pasta Shops', 'Vegetarian, Vegan, Gluten-Free',
#        'American (New), Colombian, Venezuelan', 'Hot Pot, Japanese',
#        'Cocktail Bars, Tacos', 'Steakhouses, Burgers, Cocktail Bars',
#        'Caribbean, Hawaiian, Venues & Event Spaces',
#        'Bars, Italian, Pizza',
#        'American (New), Breakfast & Brunch, Beer Bar',
#        'Seafood, Sushi Bars, Tacos', 'Breakfast & Brunch',
#        'American (New), Italian, Cocktail Bars', 'Thai, Food Trucks',
#        'Chicken Shop, Thai', 'Soul Food, American (Traditional)',
#        'American (Traditional), Barbeque, Burgers',
#        'Soul Food, Seafood, Southern', 'Soul Food, Southern, Sandwiches',
#        'Singaporean, Malaysian, Halal', 'Food Trucks, Pop-Up Restaurants',
#        'Seafood, Japanese, Pop-Up Restaurants',
#        'Chicken Shop, Thai, Hainan', 'Japanese, Steakhouses',
#        'Breakfast & Brunch, Korean',
#        'Mediterranean, Food Delivery Services, Caterers',
#        'Coffee & Tea, Waffles, Cafes',
#        'Latin American, Lounges, Cocktail Bars',
#        'Laotian, Asian Fusion, Thai', 'Greek, Mediterranean, Desserts',
#        'Sandwiches, Pizza', 'Korean, Bars', 'Beer Gardens, American (New)',
#        'Sandwiches, Vietnamese, Juice Bars & Smoothies',
#        'Steakhouses, Burgers, Sandwiches', 'Japanese, Sushi Bars, Poke',
#        'Chinese, Delis', 'Hot Pot',
#        'Izakaya, Tapas/Small Plates, Cocktail Bars',
#        'Spanish, American (New)', 'Bakeries, Pop-Up Restaurants, Caterers',
#        'Mexican, Beer, Wine & Spirits', 'Hot Pot, Chinese, Buffets',
#        'Russian, Modern European', 'Japanese, Hot Pot', 'Barbeque',
#        'Hot Dogs, Food Trucks, Caterers', 'Tapas Bars, Izakaya',
#        'American (New), Breakfast & Brunch, Bars', 'Dim Sum, Hot Pot',
#        'Peruvian', 'Portuguese, Cocktail Bars',
#        'Himalayan/Nepalese, Indian, Caterers',
#        'American (Traditional), Bars',
#        'American (New), Venues & Event Spaces, Bars',
#        'American (New), Breakfast & Brunch, Public Services & Government',
#        'Food Stands', 'Food Stands, Korean, Barbeque',
#        'Indian, Halal, Pakistani', 'Wine Bars, Beer Bar, American (New)',
#        'American (New), Breakfast & Brunch, Gastropubs',
#        'Wine Bars, Beer Bar, Latin American',
#        'Italian, Steakhouses, Breakfast & Brunch',
#        'Seafood, Fish & Chips, Italian',
#        'American (New), French, Wine Bars', 'Seafood, Bars, Sandwiches',
#        'Seafood, Bars', 'Pizza, Italian, Wine Bars',
#        'Middle Eastern, Persian/Iranian', 'Szechuan, Noodles, Hot Pot',
#        'Asian Fusion', 'Food Trucks, Barbeque',
#        'Juice Bars & Smoothies, Acai Bowls, Wraps', 'Taiwanese, Fast Food',
#        'Burgers, Sports Bars, American (Traditional)',
#        'Breakfast & Brunch, Sandwiches, Latin American',
#        'Japanese, Poke, Hawaiian', 'Desserts, Noodles, Cafes',
#        'Chinese, Noodles, Pancakes', 'Dim Sum, Bakeries',
#        'Indonesian, Malaysian, Singaporean',
#        'Sandwiches, Coffee & Tea, Vietnamese', 'Hot Pot, Chinese',
#        'Chinese, Hong Kong Style Cafe', 'Japanese, Asian Fusion',
#        'Diners, Breakfast & Brunch, American (Traditional)',
#        'Italian, Pasta Shops, Pizza', 'Thai, Noodles, Ramen', 'Polynesian',
#        'American (New), Moroccan, Ethiopian', 'Food Trucks, Taiwanese',
#        'Himalayan/Nepalese, Wine Bars', 'Pubs, British',
#        'Food Trucks, Filipino', 'Japanese, Cafes', 'Noodles, Dim Sum',
#        'Thai, Noodles, Beer, Wine & Spirits', 'Food Trucks, Tacos',
#        'Steakhouses, Seafood, American (New)',
#        'Cocktail Bars, Tacos, American (Traditional)',
#        'Latin American, Tacos, Tapas/Small Plates',
#        'Wine Bars, Tapas/Small Plates, Whiskey Bars',
#        'Indian, Cocktail Bars', 'Chinese, American (Traditional)',
#        'Pizza, Salad, Sandwiches', 'Indian, Vegetarian',
#        'Food Delivery Services, American (New), Sandwiches',
#        'Indian, Food Delivery Services', 'Pizza, Sandwiches, Salad',
#        'Soul Food, Breakfast & Brunch, Chicken Wings',
#        'Cafes, Coffee & Tea, Breakfast & Brunch',
#        'Cocktail Bars, Tapas/Small Plates, Sports Bars',
#        'Chicken Wings, Fast Food, Seafood', 'Chicken Wings',
#        'Acai Bowls, Salad'], dtype=object)

# %%
df_restaurants.groupby('pickup_delivery').count()
# Out:
#                              ids  names  rating  review_count  price  \
# pickup_delivery
# neither pickup nor delivery   20     20      20            20     14
# only delivery                762    762     762           762    690
# only pickup                   57     57      57            57     55
# pickup and delivery          979    979     979           979    735
#
#                              transactions  is_closed  type_food  \
# pickup_delivery
# neither pickup nor delivery            20         20         20
# only delivery                         762        762        762
# only pickup                            57         57         57
# pickup and delivery                   979        979        979
#
#                              type_food_alias  latitude  longitude  country  \
# pickup_delivery
# neither pickup nor delivery               20        20         20       20
# only delivery                            762       762        762      762
# only pickup                               57        57         57       57
# pickup and delivery                      979       979        979      979
#
#                              state  city  zip_code  purchase
# pickup_delivery
# neither pickup nor delivery     20    20        20        20
# only delivery                  762   762       762       762
# only pickup                     57    57        57        57
# pickup and delivery            979   979       979       979

# %%
df_restaurants.to_csv('../data/processed/yelp_SF.csv', index=False)
