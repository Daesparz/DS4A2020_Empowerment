# %% [markdown]
# ### Install and import Pandas

# %%
import pandas as pd

# %% [markdown]
# ### Locate file and import file to dataframe (df)

# %%
df = pd.read_excel("Consolidated_Data.xlsx") 
df.head()
# Out:
#                                                 Data  \
# 0  Table 1. Real Gross Domestic Product and Relat...
# 1  Table 1. Real Gross Domestic Product and Relat...
# 2  Table 1. Real Gross Domestic Product and Relat...
# 3  Table 1. Real Gross Domestic Product and Relat...
# 4  Table 1. Real Gross Domestic Product and Relat...
#
#                         Economic Row Year_2012 Year_2013 Year_2014 Year_2015  \
# 0       Gross domestic product (GDP)         -         -         -         -
# 1  Personal consumption expenditures         -         -         -         -
# 2                              Goods         -         -         -         -
# 3                      Durable goods         -         -         -         -
# 4                   Nondurable goods         -         -         -         -
#
#   Q3_2016 Q4_2016 Year_2016 Q1_2016   ...    JAN_2020 FEB_2020 MAR_2020  \
# 0     2.2     2.5         -     2.3   ...           -        -        -
# ...

# %% [markdown]
# ### Check if there are NaN or Null values

# %%
print(df.isnull().values.any())
# Out:
# False

# %%
print(df.isnull().sum())
# Out:
# Data            0
# Economic Row    0
# Year_2012       0
# Year_2013       0
# Year_2014       0
# Year_2015       0
# Q3_2016         0
# Q4_2016         0
# Year_2016       0
# Q1_2016         0
# Q2_2017         0
# Q3_2017         0
# Q4_2017         0
# Year_2017       0
# Q1_2017         0
# Q2_2018         0
# Q3_2018         0
# Q4_2018         0
# Year_2018       0
# Q1_2018         0
# Q2_2019         0
# Q3_2019         0
# Q4_2019         0
# Year_2019       0
# Q1_2020         0
# Q2_2020         0
# Q3_2020         0
# Year_2020       0
# JAN_2019        0
# FEB_2019        0
# MAR_2019        0
# APR_2019        0
# MAY_2019        0
# JUN_2019        0
# JUL_2019        0
# AUG_2019        0
# SEP_2019        0
# OCT_2019        0
# NOV_2019        0
# DEC_2019        0
# JAN_2020        0
# FEB_2020        0
# MAR_2020        0
# APR_2020        0
# MAY_2020        0
# JUN_2020        0
# JUL_2020        0
# AUG_2020        0
# SEP_2020        0
# OCT_2020        0
# ...

# %% [markdown]
# ### GroupBy Table Aggregated. Test out that it's organized by table and showcase # of rows that correspond to it.

# %%
df_table = df.groupby("Data").count()
df_table
# Out:
#                                                     Economic Row  Year_2012  \
# Data
# Table 1. Real Gross Domestic Product and Relate...            12         12
# Table 1.5.1. Percent Change From Preceding Peri...            62         62
# Table 1.5.2. Contributions to Percent Change in...            64         64
# Table 1.5.3. Real Gross Domestic Product, Expan...            62         62
# Table 10. Corporate Profits by Industry: Level ...             1          1
# Table 12. Real Gross Domestic Product by Indust...            30         30
# Table 14. Gross Domestic Product by Industry Gr...            30         30
# Table 16. Real Gross Output by Industry Group: ...            30         30
# Table 17. Gross Output by Industry Group: Level...            30         30
# Table 2. Contributions to Percent Change in Rea...            15         15
# Table 2.8.7. Percent Change From Preceding Peri...            11         11
# ...
